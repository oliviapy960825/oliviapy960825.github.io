# %% [markdown]
# # Assignment 02 - Dynamo
# *EMSE 6586 - DBMS for Analytics*
#
# Due: **2/26/2019 @ 11:59pm**

# %% [markdown]
# *Notes:*
#  - All code should follow the PEP 8 Style Guide for Python
#  - Assignment should be submitted using jupyter notebooks
#   - File name should follow “{Your Name} – Assignment_XX_Submission”
#   - Each Task should be contained in its own cell
#   - Each Task should be properly commented
#   - Each Task should print out the answer to the Task if appropriate
#   - Sample submission can be found on blackboard
#   - **Not following these standards may result in lost points**

# %% [markdown]
# # Task 1
#
# Write a boto3 scan query that will find tweets, in the twitter_statuses table, that have a retweet_count greater than 5000.

# %%
"""
task 1 is a boto3 scan query to find tweets that have retweet_count that is greater than 5000
from table twitter_statuses and store them in variable item
"""
import boto3 #This is the module we will need
from boto3.dynamodb.conditions import Key, Attr
#This creates our dynamo resource object
dynamo = boto3.resource('dynamodb', #First we define the resource we are connecting to
                region_name='us-east-2', #The region that the resource lies
                aws_access_key_id='AKIAIUIBT5HDTW7CEHWQ', #Our AWS access key (AWS console)
                aws_secret_access_key='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', #Our secret key (generated once)
)

table= dynamo.Table('twitter_statuses')
print(dir(table))
item = table.scan(
    FilterExpression=Key('retweet_count').gt(5000)) 

print(len(item['Items']))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_injector', '_name', 'attribute_definitions', 'batch_writer', 'billing_mode_summary', 'creation_date_time', 'delete', 'delete_item', 'get_available_subresources', 'get_item', 'global_secondary_indexes', 'item_count', 'key_schema', 'latest_stream_arn', 'latest_stream_label', 'load', 'local_secondary_indexes', 'meta', 'name', 'provisioned_throughput', 'put_item', 'query', 'reload', 'restore_summary', 'scan', 'sse_description', 'stream_specification', 'table_arn', 'table_id', 'table_name', 'table_size_bytes', 'table_status', 'update', 'update_item', 'wait_until_exists', 'wait_until_not_exists']
# 451

# %%
"""
try to print out one item in item list and have a look at the attriutes
"""
print(item['Items'][0])
# Out:
# {'hashtags': [], 'urls': [{'expanded_url': 'https://twitter.com/i/web/status/1055064484644089856', 'url': 'https://t.co/7E2YNgkXR0'}], 'created_at': 'Wed Oct 24 11:52:29 +0000 2018', 'user_mentions': [], 'user': {'friends_count': Decimal('45'), 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', 'listed_count': Decimal('98846'), 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'favourites_count': Decimal('7'), 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'description': '45th President of the United States of America🇺🇸', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'screen_name': 'realDonaldTrump', 'id_str': '25073877', 'profile_link_color': '1B95E0', 'geo_enabled': True, 'id': Decimal('25073877'), 'profile_background_color': '6D5C18', 'lang': 'en', 'profile_sidebar_border_color': 'BDDCAD', 'profile_text_color': '333333', 'verified': True, 'profile_
# ...

# %% [markdown]
# # Task 2
#
# Create a TwitterStatus object with the following attributes:
#  - created_date (datetime)
#  - description (string)
#  - favorites_count (int)
#  - friends_count (int)
#  - id_str (string)
#  - listed_count (int)
#  - location (string)
#  - name (string)
#  - screen_name (string)
#  - statuses_count (int)
#  - url (string)
#  - verified (book)
#  - hashtags (list of strings)
#  - user_mentions (list of dicts)
#  - student_name (string)
#
# *Note: The student_name attribute should be your full name, it will be used for tracking purposes in the database*

# %%
class TwitterStatus():
    """
    TwitterStatus class has attributes: created_date, description, favorites_count, friends_count,
    id_str, listed_count, location, name, screen_name, statuses_count, url, verified, hashtags, user_mentions,
    retweet_count and student_name
    TwitterStatus class has a method: to_json, which includes every attribute of TwitterStatus class and make
    a json format string and return the json string
    """
    def __init__(self, item):
        """
        This is the initialization method of the TwitterStatus class
        Args:
        self, item
        Returns:
        none
        """
        self.created_date=item['created_at']
        self.description=item['user'].get('description')
        self.favorites_count=str(item['user'].get('favorites_count'))
        self.friends_count=str(item['user'].get('friends_count'))
        self.id_str=str(item['id_str'])
        self.listed_count=str(item['user'].get('listed_count'))
        self.location=item['user'].get('location')
        self.name=item['user'].get('name')
        self.screen_name=item['user'].get('screen_name')
        self.statuses_count=str(item['user'].get('statuses_count'))
        self.url=item['user'].get('url')
        self.verified=item['user'].get('verified')
        self.hashtags=item['hashtags']
        self.user_mentions=str(item['user_mentions'])
        self.retweet_count=str(item['retweet_count'])
        self.student_name="Wang Peiyu"
        
        
    def to_json(self):
        """
        This method takes the attrbiutes of TwitterStatus class and return a json format string
        Args:
        self
        return:
        json_string(string)-json format string
        """
        json_string={
                'created_date':self.created_date,
                'description':self.description,
                'favorites_count':self.favorites_count,
                'friends_count':self.friends_count,
                'id_str':self.id_str,
                'listed_count':self.listed_count,
                'location':self.location,
                'name':self.name,
                'screen_name':self.screen_name,
                'statuses_count':self.statuses_count,
                'url':self.url,
                'verified':self.verified,
                'hashtags':self.hashtags,
                'user_mention':self.user_mentions,
                'student_name':self.student_name
            }
        return (json_string)

# %% [markdown]
# # Task 3
#
# Add a method to your TwitterStatus object called **to_json** that will convert the attributes in the TwitterStatus object back into a json representation.
#
# *Note: Your method should simply return the json formatted string. Be careful about the date field.*

# %%
###to_json method added in the previous block



#print(item['Items'])
print(item.get('Items',{}))
# Out:
# [{'hashtags': [], 'urls': [{'expanded_url': 'https://twitter.com/i/web/status/1055064484644089856', 'url': 'https://t.co/7E2YNgkXR0'}], 'created_at': 'Wed Oct 24 11:52:29 +0000 2018', 'user_mentions': [], 'user': {'friends_count': Decimal('45'), 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg', 'listed_count': Decimal('98846'), 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'favourites_count': Decimal('7'), 'created_at': 'Wed Mar 18 13:46:38 +0000 2009', 'description': '45th President of the United States of America🇺🇸', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'screen_name': 'realDonaldTrump', 'id_str': '25073877', 'profile_link_color': '1B95E0', 'geo_enabled': True, 'id': Decimal('25073877'), 'profile_background_color': '6D5C18', 'lang': 'en', 'profile_sidebar_border_color': 'BDDCAD', 'profile_text_color': '333333', 'verified': True, 'profile
# ...

# %% [markdown]
# # Task 4
#
# Use the query from **Task 1** to generate a list of TwitterStatus objects. Take the generated list and sort it, in descending order, by the ***retweet_count*** attribute.

# %%
"""
For task 4, every tweet in item list is extracted out and then converted into a TwitterStatus object
TwitterStatuses and then appended to twitter_statuses_list. After that twitter_statuses_list is sorted
in descending order based on the retweet_count attribute of every object
"""
twitter_statuses_list=[]
#print(item.get('Items',{}))
for i in item.get('Items',{}):
    #print(i)
    #print(i['urls'][0].get('url'))
    TwitterStatuses=TwitterStatus(i)
    
    #print(TwitterStatuses.retweet_count)
    twitter_statuses_list.append(TwitterStatuses)
#print(twitter_statuses_list)
    #print(TwitterStatuses)
    #print(dir(TwitterStatuses))
#print(twitter_statuses_list[0])
#print(dir(twitter_statuses_list[0]))
#print(twitter_statuses_list[0].__getattribute__)
newStatuses=sorted(twitter_statuses_list, key=lambda x:int(x.retweet_count),reverse=True)

##test to see if newStatuses is sorted in descending order based on retweet_count
for i in newStatuses:
    
    print(i.retweet_count)
# Out:
# 114549
# 82469
# 76379
# 59714
# 51499
# 49506
# 49402
# 45474
# 45160
# 44564
# 44156
# 43348
# 43314
# 41589
# 41546
# 41226
# 41125
# 41051
# 40666
# 40618
# 40406
# 40037
# 39160
# 38904
# 38475
# 38308
# 37813
# 37704
# 37595
# 37072
# 36709
# 36510
# 36464
# 36316
# 36045
# 35868
# 35517
# 35449
# 34955
# 34805
# 34609
# 34324
# 33684
# 33574
# 33385
# 33342
# 32895
# 32350
# 31964
# 31684
# 31675
# 31573
# 31515
# 31497
# 31309
# 31308
# 31105
# 30904
# 30725
# 30555
# 30336
# 30327
# 30302
# 30160
# 30008
# 29410
# 29172
# 29107
# 29076
# 28952
# 28934
# 28856
# 28752
# 28673
# 28631
# 28529
# 28524
# 28426
# 28377
# 28362
# 28088
# 27879
# 27861
# 27826
# 27794
# 27699
# 27699
# 27693
# 27646
# 27577
# 27522
# 27281
# 27244
# 27205
# 27176
# 27158
# 27147
# 27124
# 27111
# 26887
# 26770
# 26717
# 26308
# 26216
# 26025
# 25958
# 25930
# 25760
# 25720
# 25471
# 25383
# 25205
# 25192
# 25121
# 25119
# 25114
# 25112
# 25051
# 24998
# 24987
# 24939
# 24917
# 24896
# 24838
# ...

# %% [markdown]
# # Task 5
#
# Insert the top/first 10 **TwitterStatus** objects from **Task 4** into the student_status collection in our **MonogDB instance**

# %%
"""
For Task 5, the json format string of the first 10 TwitterStatus objects in newStatuses 
are inserted into the student_status collection in MongoDB
"""
from pymongo import MongoClient

client = MongoClient(host='3.17.135.90', #host is the hostname for the database
                     port=27017, #port is the port number that mongo is running on
                     username='student', #username for the db
                     password='emse6992pass', #password for the db
                     authSource='emse6992') #Since our user only exists for the emse6992 db, we need to specify this
db = client.emse6992
table = db.student_status
#The item itself is just a dictionary of values
for i in range(0,10):
    new_item=newStatuses[i].to_json()
    print(type(new_item))
    table.insert_one(new_item)
docs = table.find({'student_name':'Wang Peiyu'})
print(docs[0])
#our_statuses = table.scan(FilterExpression=Key('student_name').eq("Wang Peiyu"))
#print(our_statuses)
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# {'_id': ObjectId('5c6f3b64dfd8ff3c5c841351'), 'created_date': 'Tue Jul 10 11:38:10 +0000 2018', 'description': '45th President of the United States of America🇺🇸', 'favorites_count': 'None', 'friends_count': '45', 'id_str': '1016647764434931713', 'listed_count': '98846', 'location': 'Washington, DC', 'name': 'Donald J. Trump', 'screen_name': 'realDonaldTrump', 'statuses_count': '40220', 'url': 'https://t.co/OMxB0x7xC5', 'verified': True, 'hashtags': [], 'user_mention': "[{'name': 'Donald J. Trump', 'id': Decimal('25073877'), 'screen_name': 'realDonaldTrump', 'id_str': '25073877'}]", 'student_name': 'Wang Peiyu'}

# %%
# Out:
# dynamodb.Table(name='student_status')
